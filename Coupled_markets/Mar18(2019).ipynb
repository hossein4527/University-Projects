# %% [markdown]
# # A short review of the work (Mass Considered) untill now

# %% [markdown]
# In date March 18 2019, 2 days befor Norooz, I am reviewing the project and plot the final results.

# %%
import my_packs as cm
import pandas as pd

# %%
market1_data = pd.read_csv('data-s&p.csv')
mass_df = pd.read_csv('mass_dataFrame.csv')

# %%
mass_df
# Out:
#              Date  S&P 500 COMPOSITE MASS (Vol/Out)  FTSE 100 MASS (Vol/Out)  \
# 0      1974-01-03                               NaN                      NaN
# 1      1974-01-04                               NaN                      NaN
# 2      1974-01-07                               NaN                      NaN
# 3      1974-01-08                               NaN                      NaN
# 4      1974-01-09                               NaN                      NaN
# 5      1974-01-10                               NaN                      NaN
# 6      1974-01-11                               NaN                      NaN
# 7      1974-01-14                               NaN                      NaN
# 8      1974-01-15                               NaN                      NaN
# 9      1974-01-16                               NaN                      NaN
# 10     1974-01-17                               NaN                      NaN
# ...
