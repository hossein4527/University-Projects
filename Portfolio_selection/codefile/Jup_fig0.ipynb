# %%
import pandas as pd
import numpy as np
from mod_genetic import run_genetic as rg
from mod_packs import quantum_potential as qp
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/lib/python3.8/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.kde module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
price_df = pd.read_excel('PRICE INDEX.xlsx').dropna().set_index('Date')
price_val = price_df.T.values
names = [price_df.columns[i][:3] for i in range(8)]
snp_return = qp.scaled_return(price_val[0],1)
data = snp_return[-1000:]

# %%
# price_df[4700:-300]

# %%
x , pot_port = qp.numpy_qpot(data , 0.0005)
d , u = qp.risk_data_input(data , 0.0005)

# %%
xxx = price_df.iloc[-1000:].index.year
new_x = np.linspace(min(xxx), max(xxx), len(xxx))

# %%
y = pot_port[:-42]
xx = x[:-42]

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot( new_x , data ,'.-' ,linewidth=1.2)
# plt.xlim(d-0.001,u+0.001)
plt.xticks([2015,2016 , 2017,2018 , 2019])
ax.set_xlabel('Time', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
# plt.savefig('fig0_a.svg', format='svg', dpi=300, bbox_inches='tight')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot(xx , np.array(y)/500 ,'black', linewidth=6)
# plt.xlim(d-0.001,u+0.001)
plt.annotate("", xy=(d , 0.6 ), xytext=( u , 0.6) , arrowprops=dict(arrowstyle="<->" , linewidth=5  , alpha=0.6, color='blue') , label='hello')
plt.text(-0.0065, 0.68, 'Quantum Risk', size=18, rotation=0,color='blue',
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.9, 0.8),))

ax.set_xlabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Quantum potential', fontsize=13, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.grid(True)
plt.savefig('fig0_bnew.png', format='png', dpi=300, bbox_inches='tight')

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot(xx , np.array(y)/500 , linewidth=8)
# plt.xlim(d-0.001,u+0.001)
plt.annotate("", xy=(d , 0.6 ), xytext=( u , 0.6) , arrowprops=dict(arrowstyle="<->" , linewidth=5  , alpha=0.6, color='red') , label='hello')
plt.text(-0.001, 0.68, str(np.round(u-d,2)), size=18, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.8, 0.8),))

ax.set_xlabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Risk', fontsize=15, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.grid(True)
plt.axis(False)
plt.savefig('fig0_1b.png', dpi=300, bbox_inches='tight' , transparent=True)

# %%
dataa = qp.scaled_return(price_val[5],1)
data = dataa[-4000:]

x , pot_port = qp.numpy_qpot(data , 0.0005)
d , u = qp.risk_data_input(data , 0.0005)

xxx = price_df.iloc[-4000:].index.year
new_x = np.linspace(min(xxx), max(xxx), len(xxx))

y = pot_port[50:-45]
xx = x[50:-45]

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot(xx , np.array(y)/500 , linewidth=8 , color='red')
# plt.xlim(d-0.001,u+0.001)
plt.annotate("", xy=(d , 0.6 ), xytext=( u , 0.6) , arrowprops=dict(arrowstyle="<->" , linewidth=5  , alpha=0.6, color='brown') , label='hello')
plt.text(0.003, 0.68, str(np.round(u-d,2)), size=18, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.8, 0.8),))

ax.set_xlabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Risk', fontsize=15, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.grid(True)
plt.axis(False)
plt.savefig('fig0_1b.png', dpi=300, bbox_inches='tight' , transparent=True)

# %%
dataa = qp.scaled_return(price_val[0],1)
data = dataa[-1000:]

x , pot_port = qp.numpy_qpot(data , 0.0005)
d , u = qp.risk_data_input(data , 0.0005)

xxx = price_df.iloc[-1000:].index.year
new_x = np.linspace(min(xxx), max(xxx), len(xxx))

y = pot_port[:-42]
xx = x[:-42]

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot(xx , np.array(y)/500 , linewidth=8 , color='purple')
# plt.xlim(d-0.001,u+0.001)
plt.annotate("", xy=(d , 0.6 ), xytext=( u , 0.6) , arrowprops=dict(arrowstyle="<->" , linewidth=5  , alpha=0.6, color='brown') , label='hello')
plt.text(-0.005, 0.68, str(np.round(u-d,2)), size=18, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.8, 0.8),))

ax.set_xlabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Risk', fontsize=15, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.grid(True)
plt.axis(False)
plt.savefig('fig0_1a.png', dpi=300, bbox_inches='tight' , transparent=True)

# %%
dataa = qp.scaled_return(price_val[7],1)
data = dataa[-2650:]

x , pot_port = qp.numpy_qpot(data , 0.0005)
d , u = qp.risk_data_input(data , 0.0005)

xxx = price_df.iloc[-2650:].index.year
new_x = np.linspace(min(xxx), max(xxx), len(xxx))

y = pot_port[12:-36]
xx = x[12:-36]

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot(xx , np.array(y)/500 , linewidth=8 , color='blue')
# plt.xlim(d-0.001,u+0.001)
plt.annotate("", xy=(d , 0.6 ), xytext=( u , 0.6) , arrowprops=dict(arrowstyle="<->" , linewidth=5  , alpha=0.6, color='brown') , label='hello')
plt.text(-0.001, 0.68, str(np.round(u-d,2)), size=18, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.8, 0.8),))

ax.set_xlabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Risk', fontsize=15, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.grid(True)
plt.axis(False)
plt.savefig('fig0_1c.png', dpi=300, bbox_inches='tight' , transparent=True)

# %%
dataa = qp.scaled_return(price_val[0],1)
data = dataa[-2600:]

x , pot_port = qp.numpy_qpot(data , 0.0005)
d , u = qp.risk_data_input(data , 0.0005)

xxx = price_df.iloc[-2600:].index.year
new_x = np.linspace(min(xxx), max(xxx), len(xxx))

y = pot_port[26:-26]
xx = x[26:-26]

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(5,3.5))

plt.plot(xx , np.array(y)/500 , linewidth=8 , color='cyan')
# plt.xlim(d-0.001,u+0.001)
plt.annotate("", xy=(d , 0.6 ), xytext=( u , 0.6) , arrowprops=dict(arrowstyle="<->" , linewidth=5  , alpha=0.6, color='brown') , label='hello')
plt.text(-0.001, 0.68, '0.10', size=18, rotation=0,
             ha="center", va="center",
             bbox=dict(boxstyle="round",
                       ec=(1., 0.5, 0.5),
                       fc=(1., 0.8, 0.8),))

ax.set_xlabel('Return', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('Risk', fontsize=15, fontweight='black', color = '#333F4B')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.grid(True)
plt.axis(False)
plt.savefig('fig0_1d.png', dpi=300, bbox_inches='tight' , transparent=True)
