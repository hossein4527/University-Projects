# %%
import pandas as pd
import numpy as np
from genetic import run_genetic as rg
from my_packs import quantum_potential as qp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price_df = pd.read_csv('topten.csv').dropna().set_index('Date')
price_val = price_df.T.values
names = [price_df.columns[i][:3] for i in range(10)]

# %%
fit = np.load('topten30_1000_3_1o5_1o5_0005.npy' , allow_pickle=True)
# fit1 = np.load('final_fitness20_1000_4_3_3_0005.npy' , allow_pickle=True)
# fit2 = np.load('final_fitness30_10000_3_4_3_0005.npy' , allow_pickle=True)
# fit3 = np.load('final_fitness30_5000_3_4_3_0005.npy' , allow_pickle=True)
# fit4 = np.load('final_fitness40_2000_3_2_1o5_0005.npy' , allow_pickle=True)

# %%
plt.plot(fit[0:1000,0],'o-')

# %%
test = sorted((fit[:39,0])/max(fit[:39,0]), reverse=True)

# %%
plt.plot(sorted(test[:-6] , reverse=True),'.')

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
fig, ax = plt.subplots(figsize=(8,5.5))

plt.plot(np.arange(len(test[:-11])),test[:-11],'o--' , color='black' , alpha=0.4)
plt.plot([len(test[:-5-6])],test[-5-6:-4-6],'o-' , color='red' , alpha=0.9)
plt.plot([len(test[:-4-6])],test[-4-6:-3-6],'o-' , color='gold' , alpha=0.9)
plt.plot([len(test[:-3-6])],test[-3-6:-2-6],'o-' , color='cyan' , alpha=0.9)
plt.plot([len(test[:-2-6])],test[-2-6:-1-6],'o-' , color='blue' , alpha=0.9)
plt.plot([len(test[:-1-6])],test[-1-6:-6],'o-' , color='#07BA22' , alpha=0.9)

plt.xlabel('Minimizing Steps' , fontsize=15, fontweight='black', color = '#333F4B')
plt.ylabel('Quantum Risk' , fontsize=15, fontweight='black', color = '#333F4B')

plt.xticks([], [])
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
plt.savefig('topten_fig6.png', dpi=300, bbox_inches='tight' , transparent=True)

# %%
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)


fig, ax1 = plt.subplots()

ax1.plot([1,2] , [3,4],'p')
ax2 = plt.axes([1,1,1,1])
# Manually set the position and relative size of the inset axes within ax1
ip = InsetPosition(ax1, [2,2,1,1])
ax2.set_axes_locator(ip)
# Mark the region corresponding to the inset axes on ax1 and draw lines
# in grey linking the two axes.
mark_inset(ax1, ax2, loc1=2, loc2=4, fc="none", ec='0.5')

# The data: only display for low temperature in the inset figure.
ax2.plot([2],[4] , 'o')


# Some ad hoc tweaks.
# ax1.set_ylim(0,26)
# ax2.set_yticks(np.arange(0,2,0.4))
# ax2.set_xticklabels(ax2.get_xticks(), backgroundcolor='w')
# ax2.tick_params(axis='x', which='major', pad=8)

plt.show()

# %%
price_df = pd.read_excel('PRICE INDEX.xlsx').dropna().set_index('Date')
price_val = price_df.T.values
names = [price_df.columns[i][:3] for i in range(8)]
five_port_df = pd.read_csv('portfos').set_index('Unnamed: 0')
from matplotlib import rc
fig, ax = plt.subplots(figsize=(5,3.5))

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.9
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'

r = [0,1,2,3,4]
df = five_port_df
barWidth = 0.65
names = df.index
# Create green Bars
plt.bar(r, df[df.columns[0]], color='#b5ffb9', edgecolor='white', width=barWidth ,  label=df.columns[0])
plt.bar(r, df[df.columns[1]], bottom=df[df.columns[0]], color='#f9bc86', edgecolor='white', width=barWidth , label=df.columns[1])
plt.bar(r, df[df.columns[2]], bottom=[i+j for i,j in zip(df[df.columns[0]], df[df.columns[1]])], color='#a3acff', edgecolor='white', width=barWidth, label=df.columns[2])
plt.bar(r, df[df.columns[3]], bottom=[i+j+k for i,j,k in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]])], color='gold', edgecolor='white', width=barWidth , alpha=.6 , label=df.columns[3])
plt.bar(r, df[df.columns[4]], bottom=[i+j+k+l for i,j,k,l in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]])], color='greenyellow', edgecolor='white', width=barWidth , label=df.columns[4])
plt.bar(r, df[df.columns[5]], bottom=[i+j+k+l+m for i,j,k,l,m in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]] , df[df.columns[4]])], color='lightcoral', edgecolor='white', width=barWidth ,label=df.columns[5] )   
plt.bar(r, df[df.columns[6]], bottom=[i+j+k+l+m+n for i,j,k,l,m,n in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]] , df[df.columns[4]] , df[df.columns[5]])], color='grey', edgecolor='white', width=barWidth ,label=df.columns[6])
plt.bar(r, df[df.columns[7]], bottom=[i+j+k+l+m+n+o for i,j,k,l,m,n,o in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]] , df[df.columns[4]] , df[df.columns[5]] , df[df.columns[6]])], color='blueviolet', edgecolor='white', width=barWidth ,alpha=.9 , label=df.columns[7]) 

# Custom x axis
plt.xticks(r, names , fontsize=10, fontweight='black', color = '#333F4B')
plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
plt.ylabel('Percentage' , fontsize=15, fontweight='black', color = '#333F4B')

ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)

# plt.savefig('fig2.png', dpi=300, bbox_inches='tight')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
fig, ax1 = plt.subplots(figsize=(8,5))

left, bottom, width, height = [1, 0.6, 0.2, 0.2]
ax2 = fig.add_axes([left, bottom, width, height])

ax1.plot(test,'o-')
ax1.set_xticks([], [])
ax1.spines['top'].set_color('none')
ax1.spines['right'].set_color('none')

ax2.bar(r, df[df.columns[0]], color='#b5ffb9', edgecolor='white', width=barWidth ,  label=df.columns[0])
ax2.bar(r, df[df.columns[1]], bottom=df[df.columns[0]], color='#f9bc86', edgecolor='white', width=barWidth , label=df.columns[1])
ax2.bar(r, df[df.columns[2]], bottom=[i+j for i,j in zip(df[df.columns[0]], df[df.columns[1]])], color='#a3acff', edgecolor='white', width=barWidth, label=df.columns[2])
ax2.bar(r, df[df.columns[3]], bottom=[i+j+k for i,j,k in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]])], color='gold', edgecolor='white', width=barWidth , alpha=.6 , label=df.columns[3])
ax2.bar(r, df[df.columns[4]], bottom=[i+j+k+l for i,j,k,l in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]])], color='greenyellow', edgecolor='white', width=barWidth , label=df.columns[4])
ax2.bar(r, df[df.columns[5]], bottom=[i+j+k+l+m for i,j,k,l,m in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]] , df[df.columns[4]])], color='lightcoral', edgecolor='white', width=barWidth ,label=df.columns[5] )   
ax2.bar(r, df[df.columns[6]], bottom=[i+j+k+l+m+n for i,j,k,l,m,n in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]] , df[df.columns[4]] , df[df.columns[5]])], color='grey', edgecolor='white', width=barWidth ,label=df.columns[6])
ax2.bar(r, df[df.columns[7]], bottom=[i+j+k+l+m+n+o for i,j,k,l,m,n,o in zip(df[df.columns[0]], df[df.columns[1]] , df[df.columns[2]] , df[df.columns[3]] , df[df.columns[4]] , df[df.columns[5]] , df[df.columns[6]])], color='blueviolet', edgecolor='white', width=barWidth ,alpha=.9 , label=df.columns[7]) 

# Custom x axis
# ax2.set_xticks(r, names )
ax2.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
ax2.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
ax2.ylabel('Percentage' , fontsize=15, fontweight='black', color = '#333F4B')
ax2.spines['top'].set_color('none')
ax2.spines['right'].set_color('none')
ax2.spines['left'].set_smart_bounds(True)
ax2.spines['bottom'].set_smart_bounds(True)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-411816b05994> in <module>
#      21 # ax2.set_xticks(r, names )
#      22 ax2.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
# ---> 23 ax2.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
#      24 ax2.ylabel('Percentage' , fontsize=15, fontweight='black', color = '#333F4B')
#      25 ax2.spines['top'].set_color('none')
#
# AttributeError: 'Axes' object has no attribute 'setp'
